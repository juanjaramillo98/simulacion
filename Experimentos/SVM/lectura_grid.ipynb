# %%
import joblib
import pandas as pd

# %%
result=joblib.load('experimentoSVM.pkl')

# %%
resultado=pd.DataFrame(result.cv_results_)

# %%
resultado.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_C', 'param_gamma', 'param_kernel', 'params', 'split0_test_AUC',
#        'split1_test_AUC', 'split2_test_AUC', 'split3_test_AUC',
#        'split4_test_AUC', 'split5_test_AUC', 'split6_test_AUC',
#        'split7_test_AUC', 'split8_test_AUC', 'split9_test_AUC',
#        'mean_test_AUC', 'std_test_AUC', 'rank_test_AUC', 'split0_train_AUC',
#        'split1_train_AUC', 'split2_train_AUC', 'split3_train_AUC',
#        'split4_train_AUC', 'split5_train_AUC', 'split6_train_AUC',
#        'split7_train_AUC', 'split8_train_AUC', 'split9_train_AUC',
#        'mean_train_AUC', 'std_train_AUC', 'split0_test_Accuracy',
#        'split1_test_Accuracy', 'split2_test_Accuracy', 'split3_test_Accuracy',
#        'split4_test_Accuracy', 'split5_test_Accuracy', 'split6_test_Accuracy',
#        'split7_test_Accuracy', 'split8_test_Accuracy', 'split9_test_Accuracy',
#        'mean_test_Accuracy', 'std_test_Accuracy', 'rank_test_Accuracy',
#        'split0_train_Accuracy', 'split1_train_Accuracy',
#        'split2_train_Accuracy', 'split3_train_Accuracy',
#        'split4_train_Accuracy', 'split5_train_Accuracy',
#        'split6_train_Accuracy', 'split7_train_Accuracy',
#        'split8_train_Accuracy', 'split9_train_Accuracy', 'mean_train_Accuracy',
#        'std_train_Accuracy'],
#       dtype='object')

# %%
resultado[['params','mean_test_Accuracy','std_test_Accuracy','mean_test_AUC','std_test_AUC']].sort_values(['mean_test_Accuracy'], ascending=[False])
# Out:
#                                               params  mean_test_Accuracy  \
# 39         {'C': 10, 'gamma': 1, 'kernel': 'linear'}            0.731799
# 37       {'C': 10, 'gamma': 0.1, 'kernel': 'linear'}            0.731799
# 35      {'C': 10, 'gamma': 0.01, 'kernel': 'linear'}            0.731799
# 33     {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}            0.731799
# 27       {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}            0.731672
# 25      {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}            0.731672
# 29        {'C': 1, 'gamma': 0.1, 'kernel': 'linear'}            0.731672
# 31          {'C': 1, 'gamma': 1, 'kernel': 'linear'}            0.731672
# 19     {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}            0.730670
# 23        {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}            0.730670
# 17    {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}            0.730670
# 21      {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}            0.730670
# 8       {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}            0.730350
# 32        {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}            0.729991
# 24         {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}            0.729820
# 18        {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}            0.729799
# 10       {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}            0.729677
# 13     {'C': 0.01, 'gamma': 0.1, 'kernel': 'linear'}            0.729241
# 15       {'C': 0.01, 'gamma': 1, 'kernel': 'linear'}            0.729241
# 11    {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}            0.729241
# 9    {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}            0.729241
# 16       {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}            0.729160
# 26          {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}            0.727918
# 1   {'C': 0.001, 'gamma': 0.001, 'kernel': 'linear'}            0.727529
# 7       {'C': 0.001, 'gamma': 1, 'kernel': 'linear'}            0.727529
# 5     {'C': 0.001, 'gamma': 0.1, 'kernel': 'linear'}            0.727529
# 3    {'C': 0.001, 'gamma': 0.01, 'kernel': 'linear'}            0.727529
# 20         {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}            0.722087
# 34         {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}            0.721586
# 28           {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}            0.715799
# 12        {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}            0.703422
# 36          {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}            0.673008
# 2       {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}            0.637536
# 38            {'C': 10, 'gamma': 1, 'kernel': 'rbf'}            0.544152
# 30             {'C': 1, 'gamma': 1, 'kernel': 'rbf'}            0.540209
# 22           {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}            0.500000
# 14          {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}            0.500000
# 6          {'C': 0.001, 'gamma': 1, 'kernel': 'rbf'}            0.500000
# 4        {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}            0.500000
# 0      {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}            0.500000
#
#     std_test_Accuracy  mean_test_AUC  std_test_AUC
# 39           0.022394       0.810312      0.022055
# 37           0.022394       0.810312      0.022055
# 35           0.022394       0.810312      0.022055
# 33           0.022394       0.810312      0.022055
# 27           0.022554       0.810328      0.022098
# 25           0.022554       0.810328      0.022098
# 29           0.022554       0.810328      0.022098
# 31           0.022554       0.810328      0.022098
# 19           0.023884       0.810369      0.022079
# 23           0.023884       0.810369      0.022079
# 17           0.023884       0.810369      0.022079
# 21           0.023884       0.810369      0.022079
# 8            0.022276       0.809005      0.021368
# 32           0.024276       0.809738      0.021719
# 24           0.021749       0.810166      0.021428
# 18           0.022501       0.806793      0.020906
# 10           0.022377       0.806508      0.020683
# 13           0.023764       0.810403      0.021853
# 15           0.023764       0.810403      0.021853
# 11           0.023764       0.810403      0.021853
# 9            0.023764       0.810403      0.021853
# 16           0.023253       0.809419      0.021337
# 26           0.024207       0.801640      0.021852
# 1            0.023803       0.809514      0.021615
# 7            0.023803       0.809514      0.021615
# 5            0.023803       0.809514      0.021615
# 3            0.023803       0.809514      0.021615
# 20           0.023180       0.770420      0.020789
# 34           0.020448       0.787894      0.021024
# 28           0.023641       0.768895      0.020301
# 12           0.022468       0.763136      0.021698
# 36           0.021776       0.719814      0.017765
# 2            0.013335       0.806547      0.020469
# 38           0.030909       0.656559      0.016872
# 30           0.023768       0.656828      0.017004
# 22           0.000000       0.657157      0.016973
# 14           0.000000       0.657147      0.016977
# 6            0.000000       0.657129      0.016958
# 4            0.000000       0.763115      0.021713
# 0            0.000000       0.808818      0.021442
