# %%
import joblib
import pandas as pd

# %%
result=joblib.load('experimentoRNA.pkl')

# %%
resultado=pd.DataFrame(result.cv_results_)

# %%
resultado.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_activation', 'param_alpha', 'param_hidden_layer_sizes',
#        'param_max_iter', 'param_solver', 'params', 'split0_test_AUC',
#        'split1_test_AUC', 'split2_test_AUC', 'split3_test_AUC',
#        'split4_test_AUC', 'split5_test_AUC', 'split6_test_AUC',
#        'split7_test_AUC', 'split8_test_AUC', 'split9_test_AUC',
#        'mean_test_AUC', 'std_test_AUC', 'rank_test_AUC', 'split0_train_AUC',
#        'split1_train_AUC', 'split2_train_AUC', 'split3_train_AUC',
#        'split4_train_AUC', 'split5_train_AUC', 'split6_train_AUC',
#        'split7_train_AUC', 'split8_train_AUC', 'split9_train_AUC',
#        'mean_train_AUC', 'std_train_AUC', 'split0_test_Accuracy',
#        'split1_test_Accuracy', 'split2_test_Accuracy', 'split3_test_Accuracy',
#        'split4_test_Accuracy', 'split5_test_Accuracy', 'split6_test_Accuracy',
#        'split7_test_Accuracy', 'split8_test_Accuracy', 'split9_test_Accuracy',
#        'mean_test_Accuracy', 'std_test_Accuracy', 'rank_test_Accuracy',
#        'split0_train_Accuracy', 'split1_train_Accuracy',
#        'split2_train_Accuracy', 'split3_train_Accuracy',
#        'split4_train_Accuracy', 'split5_train_Accuracy',
#        'split6_train_Accuracy', 'split7_train_Accuracy',
#        'split8_train_Accuracy', 'split9_train_Accuracy', 'mean_train_Accuracy',
#        'std_train_Accuracy'],
#       dtype='object')

# %%
resultado[['params','mean_test_Accuracy','std_test_Accuracy','mean_test_AUC','std_test_AUC']].sort_values(['mean_test_Accuracy'], ascending=[False])
# Out:
#                                                params  mean_test_Accuracy  \
# 21  {'activation': 'logistic', 'alpha': 0.001, 'hi...            0.731254
# 17  {'activation': 'logistic', 'alpha': 0.01, 'hid...            0.730111
# 53  {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.729815
# 52  {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.729560
# 12  {'activation': 'logistic', 'alpha': 0.01, 'hid...            0.729210
# 15  {'activation': 'logistic', 'alpha': 0.01, 'hid...            0.729095
# 7   {'activation': 'logistic', 'alpha': 0.1, 'hidd...            0.728846
# 27  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...            0.728704
# 39  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...            0.728572
# 14  {'activation': 'logistic', 'alpha': 0.01, 'hid...            0.728326
# 22  {'activation': 'logistic', 'alpha': 0.001, 'hi...            0.728193
# 13  {'activation': 'logistic', 'alpha': 0.01, 'hid...            0.727950
# 31  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...            0.727690
# 4   {'activation': 'logistic', 'alpha': 0.1, 'hidd...            0.727554
# 41  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...            0.727462
# 3   {'activation': 'logistic', 'alpha': 0.1, 'hidd...            0.727461
# 5   {'activation': 'logistic', 'alpha': 0.1, 'hidd...            0.727447
# 1   {'activation': 'logistic', 'alpha': 0.1, 'hidd...            0.727422
# 6   {'activation': 'logistic', 'alpha': 0.1, 'hidd...            0.727298
# 19  {'activation': 'logistic', 'alpha': 0.001, 'hi...            0.727193
# 36  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...            0.727190
# 42  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...            0.727179
# 23  {'activation': 'logistic', 'alpha': 0.001, 'hi...            0.727169
# 2   {'activation': 'logistic', 'alpha': 0.1, 'hidd...            0.727131
# 45  {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.726941
# 38  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...            0.726905
# 26  {'activation': 'logistic', 'alpha': 0.001, 'hi...            0.726806
# 11  {'activation': 'logistic', 'alpha': 0.01, 'hid...            0.726660
# 34  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...            0.726531
# 40  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...            0.726528
# 50  {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.726425
# 0   {'activation': 'logistic', 'alpha': 0.1, 'hidd...            0.726309
# 48  {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.726296
# 49  {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.726033
# 10  {'activation': 'logistic', 'alpha': 0.01, 'hid...            0.725942
# 18  {'activation': 'logistic', 'alpha': 0.001, 'hi...            0.725929
# 46  {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.725906
# 8   {'activation': 'logistic', 'alpha': 0.1, 'hidd...            0.725826
# 44  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...            0.725778
# 33  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...            0.725745
# 16  {'activation': 'logistic', 'alpha': 0.01, 'hid...            0.725693
# 35  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...            0.725657
# 51  {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.725648
# 20  {'activation': 'logistic', 'alpha': 0.001, 'hi...            0.725259
# 29  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...            0.725146
# 30  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...            0.724123
# 25  {'activation': 'logistic', 'alpha': 0.001, 'hi...            0.723922
# 47  {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.723887
# 24  {'activation': 'logistic', 'alpha': 0.001, 'hi...            0.723841
# 28  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...            0.723484
# 43  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...            0.723395
# 9   {'activation': 'logistic', 'alpha': 0.01, 'hid...            0.723140
# 32  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...            0.722754
# 37  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...            0.720428
#
#     std_test_Accuracy  mean_test_AUC  std_test_AUC
# 21           0.011082       0.805818      0.013536
# 17           0.012267       0.805481      0.014150
# 53           0.013143       0.804587      0.013107
# 52           0.009369       0.805359      0.013638
# 12           0.008030       0.806207      0.012933
# 15           0.010692       0.805267      0.014103
# 7            0.011859       0.805139      0.012782
# 27           0.012078       0.804258      0.014131
# 39           0.008183       0.803074      0.014534
# 14           0.009916       0.805007      0.013932
# 22           0.010578       0.805193      0.012980
# 13           0.012936       0.805698      0.014031
# 31           0.008814       0.804239      0.013788
# 4            0.012405       0.805506      0.013257
# 41           0.010359       0.803897      0.013812
# 3            0.010384       0.805598      0.012851
# 5            0.012081       0.804894      0.013912
# 1            0.010409       0.804633      0.013908
# 6            0.010213       0.805991      0.013379
# 19           0.010905       0.804917      0.013453
# 36           0.010792       0.804305      0.013774
# 42           0.012231       0.805249      0.014139
# 23           0.009291       0.805318      0.014231
# 2            0.013735       0.804005      0.012515
# 45           0.013269       0.803308      0.013365
# 38           0.011321       0.803975      0.014442
# 26           0.009696       0.805741      0.013164
# 11           0.010410       0.805378      0.013223
# 34           0.012009       0.805038      0.012131
# 40           0.011008       0.804839      0.013400
# 50           0.012226       0.803828      0.015078
# 0            0.009393       0.804935      0.012633
# 48           0.010345       0.803835      0.013682
# 49           0.012148       0.803599      0.013448
# 10           0.011635       0.804000      0.013765
# 18           0.012733       0.805088      0.014052
# 46           0.008929       0.803479      0.009640
# 8            0.011542       0.805717      0.012966
# 44           0.012948       0.805084      0.013711
# 33           0.010872       0.805175      0.014268
# 16           0.010934       0.805367      0.013043
# 35           0.010837       0.805311      0.013121
# 51           0.011920       0.803696      0.015706
# 20           0.010134       0.804959      0.013677
# 29           0.008690       0.803076      0.012964
# 30           0.014217       0.804133      0.013392
# 25           0.014273       0.804065      0.013677
# 47           0.011645       0.803018      0.012054
# 24           0.010945       0.806691      0.013464
# 28           0.013089       0.802918      0.013858
# 43           0.014478       0.804126      0.014404
# 9            0.013545       0.803870      0.012928
# 32           0.011364       0.802781      0.014570
# 37           0.012352       0.800583      0.013889

# %%
resultado[['params','mean_test_Accuracy']].sort_values(['mean_test_Accuracy'], ascending=[False]).iloc[0]['params']
# Out:
# {'activation': 'logistic',
#  'alpha': 0.001,
#  'hidden_layer_sizes': 100,
#  'max_iter': 100,
#  'solver': 'adam'}
